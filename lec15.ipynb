# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank     Team       Won         Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys          493   367     6   0.573  1960.000    866
# 1     2    Green       Bay      Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears          744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins          439   341     4   0.563  1966.000    784
# 4     5      New   England  Patriots[b]   476   383   9.000     0.554   1960
# 5     6      New      York       Giants   684   572  33.000     0.543   1925
#
#    Total  Games Division
# 0    NFC   East      NaN
# 1  1,320    NFC    North
# 2    NFC  North      NaN
# 3    AFC   East      NaN
# 4    868    AFC     East
# 5  1,289    NFC     East

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First', 'NFL', 'Season',
#        'Total', 'Games', 'Division'],
#       dtype='object')

# %%
nfl_frame['Season']
# Out:
# 0      866
# 1     1921
# 2    1,354
# 3      784
# 4     1960
# 5     1925
# Name: Season, dtype: object

# %%
nfl_frame.Season
# Out:
# 0      866
# 1     1921
# 2    1,354
# 3      784
# 4     1960
# 5     1925
# Name: Season, dtype: object

# %%
nfl_frame[['Team','Season']]
# Out:
#       Team Season
# 0   Dallas    866
# 1    Green   1921
# 2  Chicago  1,354
# 3    Miami    784
# 4      New   1960
# 5      New   1925

# %%
DataFrame(nfl_frame, columns=['Team', 'Season'])
# Out:
#       Team Season
# 0   Dallas    866
# 1    Green   1921
# 2  Chicago  1,354
# 3    Miami    784
# 4      New   1960
# 5      New   1925

# %%
DataFrame(nfl_frame, columns=['Team', 'Season','gu'])
# Out:
#       Team Season  gu
# 0   Dallas    866 NaN
# 1    Green   1921 NaN
# 2  Chicago  1,354 NaN
# 3    Miami    784 NaN
# 4      New   1960 NaN
# 5      New   1925 NaN

# %%
nfl_frame.head(3)
# Out:
#    Rank     Team      Won     Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas  Cowboys      493   367     6   0.573  1960.000    866
# 1     2    Green      Bay  Packers   730   553  37.000     0.567   1921
# 2     3  Chicago    Bears      744   568    42   0.565  1920.000  1,354
#
#    Total  Games Division
# 0    NFC   East      NaN
# 1  1,320    NFC    North
# 2    NFC  North      NaN

# %%
nfl_frame.tail()
# Out:
#    Rank     Team       Won         Lost  Tied  Pct.   First       NFL Season  \
# 1     2    Green       Bay      Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears          744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins          439   341     4   0.563  1966.000    784
# 4     5      New   England  Patriots[b]   476   383   9.000     0.554   1960
# 5     6      New      York       Giants   684   572  33.000     0.543   1925
#
#    Total  Games Division
# 1  1,320    NFC    North
# 2    NFC  North      NaN
# 3    AFC   East      NaN
# 4    868    AFC     East
# 5  1,289    NFC     East

# %%
nfl_frame.ix[3]
# Out:
# Rank               4
# Team           Miami
# Won         Dolphins
# Lost             439
# Tied             341
# Pct.               4
# First          0.563
# NFL             1966
# Season           784
# Total            AFC
# Games           East
# Division         NaN
# Name: 3, dtype: object

# %%
nfl_frame['Stadium']="Levi's Studium"

# %%
nfl_frame
# Out:
#    Rank     Team       Won         Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys          493   367     6   0.573  1960.000    866
# 1     2    Green       Bay      Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears          744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins          439   341     4   0.563  1966.000    784
# 4     5      New   England  Patriots[b]   476   383   9.000     0.554   1960
# 5     6      New      York       Giants   684   572  33.000     0.543   1925
#
#    Total  Games Division         Stadium
# 0    NFC   East      NaN  Levi's Studium
# 1  1,320    NFC    North  Levi's Studium
# 2    NFC  North      NaN  Levi's Studium
# 3    AFC   East      NaN  Levi's Studium
# 4    868    AFC     East  Levi's Studium
# 5  1,289    NFC     East  Levi's Studium

# %%
nfl_frame['Stadium'] = np.arange(6)

# %%
nfl_frame
# Out:
#    Rank     Team       Won         Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys          493   367     6   0.573  1960.000    866
# 1     2    Green       Bay      Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears          744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins          439   341     4   0.563  1966.000    784
# 4     5      New   England  Patriots[b]   476   383   9.000     0.554   1960
# 5     6      New      York       Giants   684   572  33.000     0.543   1925
#
#    Total  Games Division  Stadium
# 0    NFC   East      NaN        0
# 1  1,320    NFC    North        1
# 2    NFC  North      NaN        2
# 3    AFC   East      NaN        3
# 4    868    AFC     East        4
# 5  1,289    NFC     East        5

# %%
stadiums = Series(["LIvi's Stadium",'AT&T Stadium'], index=[4,0])

# %%
stadiums
# Out:
# 4    LIvi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#    Rank     Team       Won         Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys          493   367     6   0.573  1960.000    866
# 1     2    Green       Bay      Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears          744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins          439   341     4   0.563  1966.000    784
# 4     5      New   England  Patriots[b]   476   383   9.000     0.554   1960
# 5     6      New      York       Giants   684   572  33.000     0.543   1925
#
#    Total  Games Division         Stadium
# 0    NFC   East      NaN    AT&T Stadium
# 1  1,320    NFC    North             NaN
# 2    NFC  North      NaN             NaN
# 3    AFC   East      NaN             NaN
# 4    868    AFC     East  LIvi's Stadium
# 5  1,289    NFC     East             NaN

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#    Rank     Team       Won         Lost  Tied  Pct.   First       NFL Season  \
# 0     1   Dallas   Cowboys          493   367     6   0.573  1960.000    866
# 1     2    Green       Bay      Packers   730   553  37.000     0.567   1921
# 2     3  Chicago     Bears          744   568    42   0.565  1920.000  1,354
# 3     4    Miami  Dolphins          439   341     4   0.563  1966.000    784
# 4     5      New   England  Patriots[b]   476   383   9.000     0.554   1960
# 5     6      New      York       Giants   684   572  33.000     0.543   1925
#
#    Total  Games Division
# 0    NFC   East      NaN
# 1  1,320    NFC    North
# 2    NFC  North      NaN
# 3    AFC   East      NaN
# 4    868    AFC     East
# 5  1,289    NFC     East

# %%
data = {'City':['SF','LA','NYC'], 'Population':[837000,388000,840000]}

# %%
data
# Out:
# {'City': ['SF', 'LA', 'NYC'], 'Population': [837000, 388000, 840000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA      388000
# 2  NYC      840000
